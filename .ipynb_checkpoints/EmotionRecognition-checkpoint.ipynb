# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (4.5.1.48)WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the 'c:\users\vedanth\appdata\local\programs\python\python36\python.exe -m pip install --upgrade pip' command.
#
# Requirement already satisfied: numpy>=1.13.3 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from opencv-python) (1.19.5)

# %%
# !pip install deepface
# Out:
# Requirement already satisfied: deepface in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (0.0.53)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from deepface) (4.56.2)
# Requirement already satisfied: keras>=2.2.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from deepface) (2.4.3)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from deepface) (3.13.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from deepface) (1.19.5)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from deepface) (4.5.1.48)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from deepface) (0.1.0)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from deepface) (0.0.4)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from deepface) (2.5.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from deepface) (8.1.0)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from deepface) (1.1.5)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from deepface) (1.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from Flask>=1.1.2->deepface) (2.11.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from Flask>=1.1.2->deepface) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from Flask>=1.1.2->deepface) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from Flask>=1.1.2->deepface) (1.0.1)
# Requirement already satisfied: six in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.12.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from gdown>=3.10.1->deepface) (2.25.1)
# Requirement already satisfied: filelock in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from gdown>=3.10.1->deepface) (3.0.12)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.1.2->deepface) (1.1.1)
# Requirement already satisfied: scipy>=0.14 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from keras>=2.2.0->deepface) (1.5.4)
# Requirement already satisfied: h5py in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from keras>=2.2.0->deepface) (3.1.0)
# Requirement already satisfied: pyyaml in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from keras>=2.2.0->deepface) (5.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from pandas>=0.23.4->deepface) (2020.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (1.26.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (3.0.4)WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the 'c:\users\vedanth\appdata\local\programs\python\python36\python.exe -m pip install --upgrade pip' command.
#
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (2020.12.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.14.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12)
# Requirement already satisfied: absl-py~=0.10 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.12.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.5.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.5.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.36.2)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.7.4.3)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.5.0.dev2021032900)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.34.1)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12.1)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.0)
# Requirement already satisfied: cached-property in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from h5py->keras>=2.2.0->deepface) (1.5.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorboard~=2.5->tensorflow>=1.9.0->deepface) (1.24.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorboard~=2.5->tensorflow>=1.9.0->deepface) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorboard~=2.5->tensorflow>=1.9.0->deepface) (0.4.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorboard~=2.5->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorboard~=2.5->tensorflow>=1.9.0->deepface) (57.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from tensorboard~=2.5->tensorflow>=1.9.0->deepface) (1.8.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=1.9.0->deepface) (4.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=1.9.0->deepface) (4.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=1.9.0->deepface) (1.3.0)
# Requirement already satisfied: importlib-metadata in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=1.9.0->deepface) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\vedanth\appdata\local\programs\python\python36\lib\site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow>=1.9.0->deepface) (3.4.0)

# %%
import cv2
from deepface import DeepFace

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
# 1.creating a video object
video = cv2.VideoCapture(0) 
# 2. Variable
a = 0
# 3. While loop
while True:
    a = a + 1
    # 4.Create a frame object
    check, frame = video.read()
    # Converting to grayscale
    #gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    # 5.show the frame!
    cv2.imshow("Capturing",frame)
    # 6.for playing 
    key = cv2.waitKey(1)
    if key == ord('q'):
        break
# 7. image saving
showPic = cv2.imwrite("photo.jpg",frame)
print(showPic)
# 8. shutdown the camera
video.release()
cv2.destroyAllWindows
# Out:
# True
# <function destroyAllWindows>

# %%
img = cv2.imread('photo.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-b09476414a5a> in <module>
# ----> 1 predictions = DeepFace.analyze(img)
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\deepface\DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend)
#     306
#     307         img_paths, bulkProcess = functions.initialize_input(img_path)
# --> 308         functions.initialize_detector(detector_backend = detector_backend)
#     309
#     310         #---------------------------------
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\deepface\commons\functions.py in initialize_detector(detector_backend)
#      45
#      46         global face_detector
# ---> 47         face_detector = FaceDetector.build_model(detector_backend)
#      48
#      49 def initializeFolder():
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\deepface\detectors\FaceDetector.py in build_model(detector_backend)
#      18
#      19     if face_detector:
# ---> 20         face_detector = face_detector()
#      21     else:
#      22         raise ValueError("invalid detector_backend passed - " + detector_backend)
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\deepface\detectors\MtcnnWrapper.py in build_model()
#       3
#       4 def build_model():
# ----> 5         from mtcnn import MTCNN
#       6         face_detector = MTCNN()
#       7         return face_detector
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\mtcnn\__init__.py in <module>
#      24 # SOFTWARE.
#      25
# ---> 26 from mtcnn.mtcnn import MTCNN
#      27
#      28
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\mtcnn\mtcnn.py in <module>
#      35
#      36 from mtcnn.exceptions.invalid_image import InvalidImage
# ---> 37 from mtcnn.network.factory import NetworkFactory
#      38
#      39
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\mtcnn\network\factory.py in <module>
#      25
#      26 from keras.layers import Input, Dense, Conv2D, MaxPooling2D, PReLU, Flatten, Softmax
# ---> 27 from keras.models import Model
#      28
#      29 import numpy as np
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\keras\__init__.py in <module>
#      18 from . import callbacks
#      19 from . import constraints
# ---> 20 from . import initializers
#      21 from . import metrics
#      22 from . import models
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\keras\initializers\__init__.py in <module>
#     122 # from ALL_OBJECTS. We make no guarantees as to whether these objects will
#     123 # using their correct version.
# --> 124 populate_deserializable_objects()
#     125 globals().update(LOCAL.ALL_OBJECTS)
#     126
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\keras\initializers\__init__.py in populate_deserializable_objects()
#      80     v2_objs = {}
#      81     base_cls = initializers_v2.Initializer
# ---> 82     generic_utils.populate_dict_with_module_objects(
#      83         v2_objs,
#      84         [initializers_v2],
#
# AttributeError: module 'keras.utils.generic_utils' has no attribute 'populate_dict_with_module_objects'

# %%
predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-fd2951b82103> in <module>
# ----> 1 predictions
#
# NameError: name 'predictions' is not defined
